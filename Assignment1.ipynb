# %%
import pandas as pd
import seaborn as sns
url="https://raw.githubusercontent.com/chiharuishida/DataVisualization/main/Penguins.csv"
Pandas=pd.read_csv(url)

# %%
Pandas
# Out:
#      Torgersen  39.1  18.7  181  3750
# 0    Torgersen  39.5  17.4  186  3800
# 1    Torgersen  40.3  18.0  195  3250
# 2    Torgersen  36.7  19.3  193  3450
# 3    Torgersen  39.3  20.6  190  3650
# 4    Torgersen  38.9  17.8  181  3625
# ..         ...   ...   ...  ...   ...
# 145      Dream  36.6  18.4  184  3475
# 146      Dream  36.0  17.8  195  3450
# 147      Dream  37.8  18.1  193  3750
# 148      Dream  36.0  17.1  187  3700
# 149      Dream  41.5  18.5  201  4000
#
# [150 rows x 5 columns]

# %%
Pandas.columns=['Island','Culmen Length','Culmen Depth','Flipper Length','Body Mass']

# %%
Pandas
# Out:
#         Island  Culmen Length  Culmen Depth  Flipper Length  Body Mass
# 0    Torgersen           39.5          17.4             186       3800
# 1    Torgersen           40.3          18.0             195       3250
# 2    Torgersen           36.7          19.3             193       3450
# 3    Torgersen           39.3          20.6             190       3650
# 4    Torgersen           38.9          17.8             181       3625
# ..         ...            ...           ...             ...        ...
# 145      Dream           36.6          18.4             184       3475
# 146      Dream           36.0          17.8             195       3450
# 147      Dream           37.8          18.1             193       3750
# 148      Dream           36.0          17.1             187       3700
# 149      Dream           41.5          18.5             201       4000
#
# [150 rows x 5 columns]

# %%
Pandas.head(5)
# Out:
#       Island  Culmen Length  Culmen Depth  Flipper Length  Body Mass
# 0  Torgersen           39.5          17.4             186       3800
# 1  Torgersen           40.3          18.0             195       3250
# 2  Torgersen           36.7          19.3             193       3450
# 3  Torgersen           39.3          20.6             190       3650
# 4  Torgersen           38.9          17.8             181       3625

# %%
Pandas.describe()
# Out:
#        Culmen Length  Culmen Depth  Flipper Length    Body Mass
# count     150.000000     150.00000      150.000000   150.000000
# mean       38.789333      18.34400      190.013333  3700.333333
# std         2.672207       1.22038        6.519961   460.084493
# min        32.100000      15.50000      172.000000  2850.000000
# 25%        36.725000      17.50000      186.000000  3350.000000
# 50%        38.800000      18.40000      190.000000  3700.000000
# 75%        40.775000      19.00000      195.000000  4000.000000
# max        46.000000      21.50000      210.000000  4775.000000

# %%
Pandas['Island'].value_counts()
# Out:
# Dream        56
# Torgersen    50
# Biscoe       44
# Name: Island, dtype: int64

# %%
Pandas.corr()
# Out:
#                 Culmen Length  Culmen Depth  Flipper Length  Body Mass
# Culmen Length        1.000000      0.391394        0.328940   0.548828
# Culmen Depth         0.391394      1.000000        0.312350   0.576114
# Flipper Length       0.328940      0.312350        1.000000   0.472188
# Body Mass            0.548828      0.576114        0.472188   1.000000

# %%
print('Correlation:')
Pandas.corr()
# Out:
# Correlation:
#                 Culmen Length  Culmen Depth  Flipper Length  Body Mass
# Culmen Length        1.000000      0.391394        0.328940   0.548828
# Culmen Depth         0.391394      1.000000        0.312350   0.576114
# Flipper Length       0.328940      0.312350        1.000000   0.472188
# Body Mass            0.548828      0.576114        0.472188   1.000000

# %%
sns.pairplot(Pandas)
